# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepgundeboina/SmallApps/blob/main/postgreSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Packages Needed

# %%
# !pip3 install psycopg2-binary
import psycopg2
import pandas as pd

# %% [markdown]
# ####Create function to Connect to DataBase

# %%
# Create function to create database

def connect_to_database():
    # Connect to database
    conn = psycopg2.connect("host=ep-summer-flower-a8ttwlet.eastus2.azure.neon.tech dbname=pet_adoption user=pet_adoption_owner password=E9RfH6azeLJV")


    # Use connection to get cursor to execute queries
    cur = conn.cursor()
    # Set automatic commit
    conn.set_session(autocommit=True)

    return cur, conn

# %%
cur, conn = connect_to_database()

# %% [markdown]
# ####Read Data into Python Pandas DataFrame

# %%
df_des=pd.read_csv('/content/drive/MyDrive/Abc/postgreSQL/description.csv',header=0,sep=',',skip_blank_lines=True,low_memory=False)
df_loc=pd.read_csv('/content/drive/MyDrive/Abc/postgreSQL/locations.csv',header=0,sep=',',skip_blank_lines=True,low_memory=False)
df_travel=pd.read_csv('/content/drive/MyDrive/Abc/postgreSQL/travel.csv',header=0,sep=',',skip_blank_lines=True,low_memory=False)

# %%
df_desc=df_des.dropna(how='all').reset_index(drop=True)
df_desc.head(5)
# Out:
#    index          id org_id  \
# 0    0.0  46042150.0  NV163
# 1    1.0  46042002.0  NV163
# 2    2.0  46040898.0   NV99
# 3    3.0  46039877.0  NV202
# 4    4.0  46039306.0  NV184
#
#                                                  url  \
# 0  https://www.petfinder.com/dog/harley-46042150/...
# 1  https://www.petfinder.com/dog/biggie-46042002/...
# 2  https://www.petfinder.com/dog/ziggy-46040898/n...
# 3  https://www.petfinder.com/dog/gypsy-46039877/n...
# 4  https://www.petfinder.com/dog/theo-46039306/nv...
#
#                     breed_primary breed_secondary      color_primary  \
# 0  American Staffordshire Terrier     Mixed Breed      White / Cream
# 1                Pit Bull Terrier     Mixed Breed  Brown / Chocolate
# 2                        Shepherd             NaN            Brindle
# 3             German Shepherd Dog             NaN                NaN
# 4                       Dachshund             NaN                NaN
#
# ...

# %%
df_locs=df_loc.dropna(how='all').reset_index(drop=True)
df_loc.head(5)
# Out:
#    index        location  exported  imported   total  inUS
# 0      0           Texas     635.0       NaN   566.0  True
# 1      1         Alabama     268.0       2.0  1428.0  True
# 2      2  North Carolina     158.0      14.0  2627.0  True
# 3      3  South Carolina     139.0      12.0  1618.0  True
# 4      4         Georgia     137.0      19.0  3479.0  True

# %%
df_trav=df_travel.dropna(how='all').reset_index(drop=True)
df_trav.head(5)
# Out:
#    index        id contact_city contact_state        found    manual remove  \
# 0      0  44520267        Anoka            MN     Arkansas       NaN    NaN
# 1      1  44698509    Groveland            FL       Abacos   Bahamas    NaN
# 2      2  45983838    Adamstown            MD         Adam  Maryland    NaN
# 3      3  44475904  Saint Cloud            MN      Adaptil       NaN   True
# 4      4  43877389       Pueblo            CO  Afghanistan       NaN    NaN
#
#   still_there
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_desc.dtypes
# Out:
# index              float64
# id                 float64
# org_id              object
# url                 object
# breed_primary       object
# breed_secondary     object
# color_primary       object
# color_secondary     object
# color_tertiary      object
# age                 object
# sex                 object
# size                object
# coat                object
# name                object
# status              object
# posted              object
# contact_city        object
# contact_state       object
# contact_zip        float64
# contact_country     object
# stateQ              object
# dtype: object

# %%
df_locs.dtypes
# Out:
# index         int64
# location     object
# exported    float64
# imported    float64
# total       float64
# inUS           bool
# dtype: object

# %%
df_trav.dtypes
# Out:
# index             int64
# id                int64
# contact_city     object
# contact_state    object
# found            object
# manual           object
# remove           object
# still_there      object
# dtype: object

# %% [markdown]
# #### Creating Tables in Database

# %%
create_description_table=("""create table if not exists description(
index INT primary key
,id INT
,org_id VARCHAR
,url VARCHAR
,breed_primary VARCHAR
,breed_secondary VARCHAR
,color_primary VARCHAR
,color_secondary VARCHAR
,color_tertiary VARCHAR
,age VARCHAR
,sex VARCHAR
,size VARCHAR
,coat VARCHAR
,name VARCHAR
,status VARCHAR
,posted VARCHAR
,contact_city VARCHAR
,contact_state VARCHAR
,contact_zip FLOAT
,contact_country VARCHAR
,stateQ VARCHAR)""")

# %%
cur.execute(create_description_table)
conn.commit()

# %%
create_loc_table=("""CREATE TABLE IF NOT EXISTS LOCATION(
index INT primary key
,location VARCHAR
,exported FLOAT
,imported FLOAT
,total FLOAT
,inUS BOOLEAN
)""")
cur.execute(create_loc_table)
conn.commit()

# %%
create_trav_table=("""CREATE TABLE IF NOT EXISTS TRAVEL(
index INT Primary key
,id	INT
,contact_city VARCHAR
,contact_state VARCHAR
,found VARCHAR
,manual VARCHAR
,remove	VARCHAR
,still_there VARCHAR
)""")
cur.execute(create_trav_table)
conn.commit()

# %% [markdown]
# ####Truncate Tables if Data Present

# %%
truncate_table=("""TRUNCATE TABLE description,LOCATION,TRAVEL""")
cur.execute(truncate_table)
conn.commit()

# %% [markdown]
# ####Insert Data into Tables in PostgreSQL DB

# %%
insert_description_table = ("""INSERT INTO description \
                (index, id, org_id, url, breed_primary, breed_secondary, \
                color_primary, color_secondary, color_tertiary, \
                age, sex, size, coat, name, status, \
                posted, contact_city, contact_state, contact_zip, \
                contact_country, stateQ)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, \
                 # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""")


# Iterating through index (i) and rows in description table
for i, row in df_desc.iterrows():
    # Pass INSERT INTO query in cur.execute() and list of data
    cur.execute(insert_description_table, list(row))

# %%
insert_loc_table = ("""INSERT INTO LOCATION (index,location,exported,imported,total,inUS)
                         VALUES (%s, %s, %s, %s, %s, %s)""")


# Iterating through index (i) and rows in description table
for i, row in df_locs.iterrows():
    # Pass INSERT INTO query in cur.execute() and list of data
    cur.execute(insert_loc_table, list(row))

# %%
insert_trav_table = ("""INSERT INTO TRAVEL (index,id,contact_city,contact_state,found,manual,remove,still_there
)
                         VALUES (%s, %s, %s, %s, %s, %s,%s,%s)""")
# Iterating through index (i) and rows in description table
for i, row in df_trav.iterrows():
    # Pass INSERT INTO query in cur.execute() and list of data
    cur.execute(insert_trav_table, list(row))
